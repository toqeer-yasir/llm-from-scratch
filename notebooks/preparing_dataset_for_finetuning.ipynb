# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path_proj_datasets = "/content/drive/MyDrive/llm_from_scratch/datasets"

# %%
os.chdir(path_proj_datasets)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/llm_from_scratch/datasets

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/llm_from_scratch/datasets/SMSSpamCollection", sep="\t")

# %%
df.head()
# Out:
#     ham  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4  spam
#
#   Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                      Ok lar... Joking wif u oni...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  U dun say so early hor... U c already then say...
# 3  Nah I don't think he goes to usf, he lives aro...
# 4  FreeMsg Hey there darling it's been 3 week's n...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ham, Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...]
# Index: []

# %%
df.columns = ['l', 't']

# %%
df.rename(columns={'l': 'Label', 't': 'Text'}, inplace=True)

# %%
df.head()
# Out:
#   Label                                               Text
# 0   ham                      Ok lar... Joking wif u oni...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  U dun say so early hor... U c already then say...
# 3   ham  Nah I don't think he goes to usf, he lives aro...
# 4  spam  FreeMsg Hey there darling it's been 3 week's n...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571 entries, 0 to 5570
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Label   5571 non-null   object
#  1   Text    5571 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.describe()
# Out:
#        Label                    Text
# count   5571                    5571
# unique     2                    5168
# top      ham  Sorry, I'll call later
# freq    4824                      30

# %%
print((df['Label'] == 'spam').sum())
print((df['Label'] == 'ham').sum())
# Out:
# 747
# 4824

# %%
ham_df = df[df['Label'] == 'ham']

# %%
len(ham_df)
# Out:
# 4824

# %%
spam_df = df[df['Label'] == 'spam']
len(spam_df)
# Out:
# 747

# %%
ham_df = ham_df.head(len(ham_df) - (len(ham_df)-747))
ham_df.head()
# Out:
#   Label                                               Text
# 0   ham                      Ok lar... Joking wif u oni...
# 2   ham  U dun say so early hor... U c already then say...
# 3   ham  Nah I don't think he goes to usf, he lives aro...
# 5   ham  Even my brother is not like to speak with me. ...
# 6   ham  As per your request 'Melle Melle (Oru Minnamin...

# %%
len(ham_df)
# Out:
# 747

# %%
spam_df['temp_key'] = range(len(spam_df))
ham_df['temp_key'] = range(len(ham_df))

# %%
spam_df['source'] = 'spam'
ham_df['source'] = 'ham'

# %%
df = pd.concat([spam_df, ham_df]).sort_values(['temp_key', 'source'])
df.drop(['temp_key', 'source'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1494, 2)

# %%
df.head()
# Out:
#   Label                                               Text
# 0   ham                      Ok lar... Joking wif u oni...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  U dun say so early hor... U c already then say...
# 4  spam  FreeMsg Hey there darling it's been 3 week's n...
# 3   ham  Nah I don't think he goes to usf, he lives aro...

# %%
len(df[df['Label'] == 'spam'])
# Out:
# 747

# %%
len(df[df['Label'] == 'ham'])
# Out:
# 747

# %%
df['Label'] = df['Label'].map({'spam': 1, 'ham': 0})

# %%
df.head()
# Out:
#    Label                                               Text
# 0      0                      Ok lar... Joking wif u oni...
# 1      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2      0  U dun say so early hor... U c already then say...
# 4      1  FreeMsg Hey there darling it's been 3 week's n...
# 3      0  Nah I don't think he goes to usf, he lives aro...
